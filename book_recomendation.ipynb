# %% [markdown]
# In this notebook I have created a Book recomender system using the KNN algorithm.
# The dataset I have used is Book Recomendation Dataset from Kaggle ([Dataset Link](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset)) <br>
# We have 3 csv files in the dataset:
# 1. Books.csv
# 2. Users.csv
# 3. Ratings.csv
#
# I have combined the 3 csv files into a single dataframe and then created a Book Recomender System using the KNN algorithm.

# %%
import numpy as np 
import pandas as pd

import os,sys, re
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Steps:
# 1. Importing Libraries
# 2. Loading the Dataset
# 3. Data Preprocessing
# 4. Creating the Book Recomender System
# 5. Testing the Book Recomender System

# %% [markdown]
# ## Loading the Dataset

# %%
df_books=pd.read_csv('./datasets/books_data/Books.csv')
df_books.head(5)
# Out:
#          ISBN  \
# 0  0195153448
# 1  0002005018
# 2  0060973129
# 3  0374157065
# 4  0393045218
#
#                                                                                            Book-Title  \
# 0                                                                                 Classical Mythology
# 1                                                                                        Clara Callan
# 2                                                                                Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It
# 4                                                                              The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# ...

# %%
df_books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
df_books.head(5)
# Out:
#          ISBN  \
# 0  0195153448
# 1  0002005018
# 2  0060973129
# 3  0374157065
# 4  0393045218
#
#                                                                                            Book-Title  \
# 0                                                                                 Classical Mythology
# 1                                                                                        Clara Callan
# 2                                                                                Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It
# 4                                                                              The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# ...

# %%
df_books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
df_books.dropna(inplace=True)

# %%
df_books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
df_ratings = pd.read_csv('./datasets/books_data/Ratings.csv')
df_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df_ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
df_ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
df_ratings.shape
# Out:
# (1149780, 3)

# %%
df_books.shape
# Out:
# (271354, 8)

# %%
## Sort the books based on the number of ratings received from each user
ratings=df_ratings['User-ID'].value_counts()
ratings.sort_values(ascending=False).head()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
# Name: User-ID, dtype: int64

# %%
len(ratings[ratings>200])
# Out:
# 899

# %%
df_ratings['User-ID'].isin(ratings[ratings < 200].index).sum()
# Out:
# 622224

# %%
ratings_with_name=df_ratings.merge(df_books,on='ISBN')

# %%
num_rating_df=ratings_with_name.groupby("Book-Title")['Book-Rating'].count().reset_index()

# %%
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df.head()
# Out:
#                                                                                                    Book-Title  \
# 0   A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)
# 1                                                                                       Always Have Popsicles
# 2                                                                        Apple Magic (The Collector's series)
# 3                                                        Ask Lily (Young Women of Faith: Lily Series, Book 5)
# 4                                                  Beyond IBM: Leadership Marketing and Finance for the 1990s
#
#    num_ratings
# 0            4
# 1            1
# 2            1
# 3            1
# 4            1

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                                                                         Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)
# 1                                                                                            Always Have Popsicles
# 2                                                                             Apple Magic (The Collector's series)
# 3                                                             Ask Lily (Young Women of Faith: Lily Series, Book 5)
# 4                                                       Beyond IBM: Leadership Marketing and Finance for the 1990s
# ...                                                                                                            ...
# 241061                                                                                               Ã?Â?lpiraten.
# ...

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                                                                         Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)
# 1                                                                                            Always Have Popsicles
# 2                                                                             Apple Magic (The Collector's series)
# 3                                                             Ask Lily (Young Women of Faith: Lily Series, Book 5)
# 4                                                       Beyond IBM: Leadership Marketing and Finance for the 1990s
# ...                                                                                                            ...
# 241061                                                                                               Ã?Â?lpiraten.
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False)

# %%
popular_df.head()
# Out:
#                                                Book-Title  num_ratings  \
# 80432   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80420        Harry Potter and the Goblet of Fire (Book 4)          387
# 80439      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80424  Harry Potter and the Order of the Phoenix (Book 5)          347
# 80412    Harry Potter and the Chamber of Secrets (Book 2)          556
#
#        avg_rating
# 80432    5.852804
# 80420    5.824289
# 80439    5.737410
# 80424    5.501441
# 80412    5.183453

# %%
popular_df = popular_df.merge(df_books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y= filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                                            254     \
# Book-Title
# 1984                                                                  9.0
# 1st to Die: A Novel                                                   0.0
# 2nd Chance                                                            0.0
# 4 Blondes                                                             0.0
# A Bend in the Road                                                    0.0
# ...                                                                   ...
# Year of Wonders                                                       0.0
# You Belong To Me                                                      0.0
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values     0.0
# Zoya                                                                  0.0
# \O\" Is for Outlaw"                                                   0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = df_books[df_books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-L'].values))
        
        data.append(item)
    
    return data

# %%
recommend('Harry Potter and the Prisoner of Azkaban (Book 3)')
# Out:
# [['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.LZZZZZZZ.jpg'],
#  ['Harry Potter and the Chamber of Secrets (Book 2)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.LZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.LZZZZZZZ.jpg']]

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.LZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.LZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.LZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.LZZZZZZZ.jpg']]

# %%
pt.index[545]
# Out:
# "The Handmaid's Tale"

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
df_books.drop_duplicates('Book-Title')
# Out:
#               ISBN  \
# 0       0195153448
# 1       0002005018
# 2       0060973129
# 3       0374157065
# 4       0393045218
# ...            ...
# 271354  0449906736
# 271356  0525447644
# 271357  006008667X
# 271358  0192126040
# 271359  0767409752
#
#                                                                                                                             Book-Title  \
# 0                                                                                                                  Classical Mythology
# 1                                                                                                                         Clara Callan
# 2                                                                                                                 Decision in Normandy
# 3                                   Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It
# ...

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(df_books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
pickle.dump(ratings_with_name,open('ratings_with_name.pkl','wb'))
